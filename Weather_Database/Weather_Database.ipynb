# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)

# %%
coordinates = list(lat_longs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
# If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %%
cities
# Out:
# ['georgetown',
#  'barentsburg',
#  'thinadhoo',
#  'chokurdakh',
#  'rikitea',
#  'vila franca do campo',
#  'praia da vitoria',
#  'coquimbo',
#  'avarua',
#  'busselton',
#  'kapaa',
#  'saint-philippe',
#  'bredasdorp',
#  'barrow',
#  'punta arenas',
#  'bluff',
#  'jamestown',
#  'narsaq',
#  'yellowknife',
#  'khowst',
#  'ambovombe',
#  'belaya gora',
#  'moengo',
#  'qaanaaq',
#  'thompson',
#  'namibe',
#  'roma',
#  'faya',
#  'neiafu',
#  'chuy',
#  'mataura',
#  'lima',
#  'nipawin',
#  'port elizabeth',
#  'dingle',
#  'san carlos de bariloche',
#  'podosinovets',
#  'amderma',
#  'clyde river',
#  'vaini',
#  'hithadhoo',
#  'manicore',
#  'ahipara',
#  'listvyagi',
#  'faanui',
#  'ribeira grande',
#  'yurimaguas',
#  'lebu',
#  'san rafael',
#  'necochea',
#  'kamenskoye',
#  'codrington',
#  'port alfred',
#  'maracacume',
#  'khatanga',
#  'illoqqortoormiut',
#  'lagoa',
#  'uglekamensk',
#  'srednekolymsk',
#  'sitka',
#  'hilo',
#  'mar del plata',
#  'atar',
#  'felidhoo',
#  'katsuura',
#  'bethel',
#  'ushuaia',
#  'albany',
#  'torbay',
#  'butaritari',
#  'taolanaro',
#  'adolfo lopez mateos',
#  'esperance',
#  'nizhneyansk',
#  'hermanus',
#  'hobart',
#  'paamiut',
#  'partenit',
#  'aksu',
#  'kruisfontein',
#  'mehamn',
#  'new norfolk',
#  'bonavista',
#  'castro',
#  'talnakh',
#  'kirakira',
#  'tumannyy',
#  'carnarvon',
#  'ponta do sol',
#  'sapernoye',
#  'victoria',
#  'dukat',
#  'iturama',
#  'pevek',
#  'izumo',
#  'belushya guba',
#  'east london',
#  'umm lajj',
#  'los llanos de aridane',
#  'longlac',
#  'atuona',
#  'hamilton',
#  'upernavik',
#  'constitucion',
#  'marolambo',
#  'norrtalje',
#  'vitimskiy',
#  'alice town',
#  'kilindoni',
#  'hurricane',
#  'cabo san lucas',
#  'bathsheba',
#  'yar-sale',
#  'cape town',
#  'souillac',
#  'tuktoyaktuk',
#  'tiksi',
#  'cherskiy',
#  'kieta',
#  'batemans bay',
#  'lang suan',
#  'warqla',
#  'high rock',
#  'palabuhanratu',
#  'jiutai',
#  'muros',
#  'wschowa',
#  'kaitangata',
#  'korla',
#  'inongo',
#  'arraial do cabo',
#  'tsienyane',
#  'luderitz',
#  'waddan',
#  'ulladulla',
#  'katubao',
#  'sibu',
#  'portland',
#  'mayor pablo lagerenza',
#  'puerto ayora',
#  'port-gentil',
#  'lompoc',
#  'seoul',
#  'nikolskoye',
#  'rungata',
#  'mocambique',
#  'nome',
#  'la ronge',
#  'kuching',
#  'fortuna',
#  'lata',
#  'aksay',
#  'saldanha',
#  'himare',
#  'rivadavia',
#  'isangel',
#  'terney',
#  'vyazemskiy',
#  'cidreira',
#  'abu samrah',
#  'sao filipe',
#  'aflu',
#  'provideniya',
#  'marsa matruh',
#  'nanortalik',
#  'lianzhou',
#  'broome',
#  'pisco',
#  'mys shmidta',
#  'linchuan',
#  'oktyabrskiy',
#  'spearfish',
#  'bouafle',
#  'broken hill',
#  'fianga',
#  'ancud',
#  'dikson',
#  'grindavik',
#  'mahebourg',
#  'aksarka',
#  'sentyabrskiy',
#  'natitingou',
#  'gunjur',
#  'sept-iles',
#  'mildura',
#  'homer',
#  'fernley',
#  'aykhal',
#  'correntina',
#  'la union',
#  'cockburn town',
#  'petatlan',
#  'saskylakh',
#  'phangnga',
#  'peniche',
#  'vaitupu',
#  'fevralsk',
#  'mendi',
#  'petropavlovsk-kamchatskiy',
#  'teguise',
#  'bandarbeyla',
#  'hambantota',
#  'rocha',
#  'tilichiki',
#  'emba',
#  'quesnel',
#  'xining',
#  'lodja',
#  'solwezi',
#  'nykoping',
#  'bambous virieux',
#  'strezhevoy',
#  'dalbeattie',
#  'agadir',
#  'berlevag',
#  'bengkulu',
#  'mudbidri',
#  'saleaula',
#  'baykit',
#  'khoy',
#  'mount hagen',
#  'tasiilaq',
#  'pearl',
#  'anloga',
#  'gimli',
#  'manzhouli',
#  'fort nelson',
#  'norman wells',
#  'ossora',
#  'huarmey',
#  'guerrero negro',
#  'piedade',
#  'tual',
#  'benguela',
#  'laguna',
#  'chumikan',
#  'coffeyville',
#  'muravlenko',
#  'sao joao da barra',
#  'waipawa',
#  'taltal',
#  'kantabanji',
#  'tsihombe',
#  'soyo',
#  'port hedland',
#  'khandagayty',
#  'montague',
#  'matagami',
#  'dmitriyevka',
#  'flinders',
#  'richards bay',
#  'gamba',
#  'port lincoln',
#  'oussouye',
#  'altay',
#  'leningradskiy',
#  'dunedin',
#  'eirunepe',
#  'fort-shevchenko',
#  'genc',
#  'pirdop',
#  'ipixuna',
#  'elizabeth city',
#  'chingirlau',
#  'khonuu',
#  'diapaga',
#  'celestun',
#  'dera din panah',
#  'tura',
#  'rock sound',
#  'lac du bonnet',
#  'kavieng',
#  'umzimvubu',
#  'maun',
#  'coruripe',
#  'tabou',
#  'khowai',
#  'samarai',
#  'dosso',
#  'lewisville',
#  'peruibe',
#  'mareeba',
#  'aktau',
#  'jalu',
#  'pacific grove',
#  'lasa',
#  'scottsburgh',
#  'buchanan',
#  'san patricio',
#  'jamsa',
#  'zheleznodorozhnyy',
#  'mbanza-ngungu',
#  'grand river south east',
#  'dakoro',
#  'beausoleil',
#  'ketchikan',
#  'saint-louis',
#  'srivardhan',
#  'cayenne',
#  'arman',
#  'attawapiskat',
#  'tuatapere',
#  'adjumani',
#  'katsina',
#  'shieli',
#  'newton stewart',
#  'sao felix do xingu',
#  'tomatlan',
#  'mao',
#  'sisimiut',
#  'stephenville',
#  'maragogi',
#  'adeje',
#  'karaton',
#  'kijang',
#  'takapau',
#  'nouadhibou',
#  'sassandra',
#  'kapit',
#  'klyuchi',
#  'moron',
#  'coahuayana',
#  'olinda',
#  'kachiry',
#  'ngunguru',
#  'naze',
#  'shache',
#  'chokwe',
#  'discovery bay',
#  'jumla',
#  'severo-kurilsk',
#  'wamba',
#  'grand bend',
#  'adrar',
#  'hisua',
#  'dibaya',
#  'fivizzano',
#  'hasaki',
#  'banda aceh',
#  'terre haute',
#  'geraldton',
#  'roebourne',
#  'anchorage',
#  'pavlovsk',
#  'olga',
#  'duluth',
#  'whitianga',
#  'gainesville',
#  'satitoa',
#  'bumba',
#  'amanganj',
#  'eureka',
#  'marystown',
#  'zhigansk',
#  'mandalgovi',
#  'samusu',
#  'iqaluit',
#  'rorvik',
#  'magadan',
#  'lavrentiya',
#  'mokhsogollokh',
#  'gazli',
#  'jutai',
#  'salalah',
#  'nsanje',
#  'coihaique',
#  'chernyshevskiy',
#  'khilok',
#  'cervo',
#  'northam',
#  'havre-saint-pierre',
#  'sioux lookout',
#  'xuddur',
#  'axim',
#  'merauke',
#  'magburaka',
#  'basco',
#  'oranjemund',
#  'tlaxco',
#  'harper',
#  'kalmunai',
#  'stornoway',
#  'pinega',
#  'ozark',
#  'paysandu',
#  'ceica',
#  'kaniama',
#  'jishui',
#  'fukue',
#  'hovd',
#  'southbridge',
#  'auki',
#  'iquitos',
#  'kizema',
#  'bintulu',
#  'majene',
#  'zvishavane',
#  'favara',
#  'komsomolskiy',
#  'te anau',
#  'alofi',
#  'kahului',
#  'virginia beach',
#  'srandakan',
#  'taseyevo',
#  'keetmanshoop',
#  'beringovskiy',
#  'lannion',
#  'tygda',
#  'yerbogachen',
#  'rafai',
#  'sale',
#  'viligili',
#  'yatou',
#  'baiquan',
#  'aklavik',
#  'palestine',
#  'phoenix',
#  'burica',
#  'shibetsu',
#  'chateaubelair',
#  'ostrovnoy',
#  'marienburg',
#  'carutapera',
#  'kingaroy',
#  'touros',
#  'kazanskoye',
#  'imisli',
#  'chiredzi',
#  'qui nhon',
#  'chimore',
#  'lang son',
#  'montrose',
#  'nianzishan',
#  'porto novo',
#  'otradnoye',
#  'yaan',
#  'miraflores',
#  'togur',
#  'padang',
#  'camopi',
#  'puerto leguizamo',
#  'gweta',
#  'nyurba',
#  'letogo',
#  'pangnirtung',
#  'santa rosa',
#  'rio gallegos',
#  'havoysund',
#  'dien bien',
#  'bose',
#  'jinchang',
#  'voznesenye',
#  'verkhoyansk',
#  'longyearbyen',
#  'baiyin',
#  'darhan',
#  'college',
#  'palmital',
#  'waingapu',
#  'manggar',
#  'henties bay',
#  'airai',
#  'kon tum',
#  'osorno',
#  'novokayakent',
#  'akdepe',
#  'boksitogorsk',
#  'pitimbu',
#  'kalulushi',
#  'fairbanks',
#  'yenagoa',
#  'port macquarie',
#  'westport',
#  'mvuma',
#  'victoria point',
#  'kayes',
#  'chadan',
#  'ayan',
#  'toftir',
#  'sahrak',
#  'sao mateus',
#  'alvaraes',
#  'hirara',
#  'omsukchan',
#  'sibolga',
#  'kuah',
#  'kodiak',
#  'meulaboh',
#  'kiama',
#  'muroto',
#  'alcantara',
#  'itarema',
#  'baherden',
#  'damietta',
#  'dudinka',
#  'pala',
#  'alyangula',
#  'ilulissat',
#  'bushehr',
#  'matara',
#  'chengde',
#  'rawlins',
#  'la orilla',
#  'pochutla',
#  'townsville',
#  'mahadday weyne',
#  'flin flon',
#  'fort walton beach',
#  'kazalinsk',
#  'conde',
#  'mahanje',
#  'wajima',
#  'amargosa',
#  'lamu',
#  'ouadda',
#  'sampit',
#  'gat',
#  'hunza',
#  'wajir',
#  'saint george',
#  'ust-koksa',
#  'taoudenni',
#  'yulara',
#  'winnemucca',
#  'abrau-dyurso',
#  'najran',
#  'omboue',
#  'kindersley',
#  'tateyama',
#  'williston',
#  'tonj',
#  'slobozia',
#  'kailua',
#  'maniitsoq',
#  'mumford',
#  'belmonte',
#  'mitsamiouli',
#  'punta alta',
#  'iskilip',
#  'fram',
#  'poso',
#  'nikolayevsk-na-amure',
#  'velsk',
#  'lakselv',
#  'amga',
#  'onguday',
#  'maroantsetra',
#  'hualmay',
#  'arinos',
#  'haicheng',
#  'ruatoria',
#  'margate',
#  'chalchihuites',
#  'antsohihy',
#  'blythe',
#  'mabaruma',
#  'dhidhdhoo',
#  'asau',
#  'varna',
#  'krasnaya gora',
#  'danjiangkou',
#  'santa barbara',
#  'poum',
#  'kozhevnikovo',
#  'masuguru',
#  'talara',
#  'kenai',
#  'los arabos',
#  'sasovo',
#  'ulcinj',
#  'bandar-e lengeh',
#  'patti',
#  'bay roberts',
#  'tabuk',
#  'mount gambier',
#  'lichtenburg',
#  'kutum',
#  'yanchukan',
#  'catia la mar',
#  'hofn',
#  'baoro',
#  'fare',
#  'bodmin',
#  'uyemskiy',
#  'antalaha',
#  'iralaya',
#  'san vicente',
#  'atambua',
#  'sterlibashevo',
#  'lancaster',
#  'never',
#  'pizarro',
#  'plettenberg bay',
#  'karratha',
#  'gushikawa',
#  'tessalit',
#  'husavik',
#  'jijiga',
#  'ladispoli',
#  'steubenville',
#  'shakawe',
#  'torrelavega',
#  'la macarena',
#  'palanga',
#  'sindou',
#  'pemangkat',
#  'phek',
#  'lilongwe',
#  'udachnyy',
#  'cadereyta',
#  'ponta delgada',
#  'riyadh',
#  'madingou',
#  'todos santos',
#  'funtua',
#  'gornopravdinsk',
#  'tromso',
#  'barberton',
#  'florianopolis',
#  'lorengau',
#  'burlington',
#  'alice springs',
#  'porto walter',
#  'port blair',
#  'anadyr',
#  'kismayo',
#  'kavaratti',
#  'viedma',
#  'nantucket',
#  'jeremoabo',
#  'christchurch',
#  'binzhou',
#  'hami',
#  'byron bay',
#  'bure',
#  'krasnoselkup',
#  'palauig',
#  'yolombo',
#  'la rioja',
#  'toliary',
#  'nynashamn',
#  'tucuman',
#  'grants',
#  'mapiri',
#  'ambilobe',
#  'dzidzantun',
#  'rach gia',
#  'san pedro',
#  'katobu',
#  'san juan',
#  'egvekinot',
#  'lyngseidet',
#  'bereda',
#  'north bend',
#  'hede',
#  'melchor de mencos',
#  'makakilo city',
#  'brandon',
#  'yeletskiy',
#  'koraput',
#  'sebrovo',
#  'houston',
#  'nhulunbuy',
#  'launceston',
#  'gravdal',
#  'tigil',
#  'alta floresta',
#  'jardim',
#  'naftah',
#  'comodoro rivadavia',
#  'along',
#  'bolungarvik',
#  'nachalovo',
#  'pueblo',
#  'mancio lima',
#  'namatanai',
#  'ixtapa',
#  'kudahuvadhoo',
#  'itoman',
#  'moindou',
#  'yumen',
#  'pimenta bueno',
#  'yarada',
#  'morant bay',
#  'karla',
#  'natal',
#  'east wenatchee bench',
#  'sabang',
#  'morehead',
#  'ha tinh',
#  'katherine',
#  'nioki',
#  'marsaxlokk',
#  'krasnyy yar',
#  'genhe',
#  'whitehorse',
#  'cozumel',
#  'qinggang',
#  'haibowan',
#  'sakakah',
#  'juneau',
#  'mayumba',
#  'shingu',
#  'pangody',
#  'sault sainte marie',
#  'smirnykh',
#  'wanning',
#  'ambatondrazaka',
#  'ayacucho',
#  'mikkeli',
#  'mazara del vallo',
#  'port hardy',
#  'port-cartier',
#  'derzhavinsk',
#  'quisqueya',
#  'bardiyah',
#  'dom pedrito',
#  'maceio',
#  'tambo',
#  'chapais',
#  'deh rawud',
#  'timizart',
#  'tambura',
#  'vardo',
#  'sioni',
#  'russell',
#  'ibotirama',
#  'mezen',
#  'huadian',
#  'sainte-suzanne',
#  'janesville',
#  'gull lake',
#  'gigmoto',
#  'kenitra',
#  'firozpur',
#  'ondjiva',
#  'mount isa',
#  'morondava',
#  'umm kaddadah',
#  'mangaratiba',
#  'neepawa',
#  'andenes',
#  'londrina',
#  'san policarpo',
#  'tabiauea',
#  'kungurtug',
#  'ewa beach',
#  'uruguaiana']

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []


print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        

    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
       
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0        
            
            
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | thinadhoo
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | praia da vitoria
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | khowst
# Processing Record 21 of Set 1 | ambovombe
# Processing Record 22 of Set 1 | belaya gora
# Processing Record 23 of Set 1 | moengo
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | thompson
# Processing Record 26 of Set 1 | namibe
# Processing Record 27 of Set 1 | roma
# Processing Record 28 of Set 1 | faya
# Processing Record 29 of Set 1 | neiafu
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | lima
# Processing Record 33 of Set 1 | nipawin
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | dingle
# Processing Record 36 of Set 1 | san carlos de bariloche
# Processing Record 37 of Set 1 | podosinovets
# Processing Record 38 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | vaini
# Processing Record 41 of Set 1 | hithadhoo
# Processing Record 42 of Set 1 | manicore
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | listvyagi
# Processing Record 45 of Set 1 | faanui
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | yurimaguas
# Processing Record 48 of Set 1 | lebu
# Processing Record 49 of Set 1 | san rafael
# Processing Record 50 of Set 1 | necochea
# Processing Record 1 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 2 | codrington
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | maracacume
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | lagoa
# Processing Record 8 of Set 2 | uglekamensk
# Processing Record 9 of Set 2 | srednekolymsk
# Processing Record 10 of Set 2 | sitka
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | atar
# Processing Record 14 of Set 2 | felidhoo
# City not found. Skipping...
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | adolfo lopez mateos
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | paamiut
# Processing Record 28 of Set 2 | partenit
# Processing Record 29 of Set 2 | aksu
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | mehamn
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | bonavista
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | kirakira
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | ponta do sol
# Processing Record 40 of Set 2 | sapernoye
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | dukat
# Processing Record 43 of Set 2 | iturama
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | izumo
# Processing Record 46 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | umm lajj
# Processing Record 49 of Set 2 | los llanos de aridane
# Processing Record 50 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | hamilton
# Processing Record 3 of Set 3 | upernavik
# Processing Record 4 of Set 3 | constitucion
# Processing Record 5 of Set 3 | marolambo
# Processing Record 6 of Set 3 | norrtalje
# Processing Record 7 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | alice town
# Processing Record 9 of Set 3 | kilindoni
# Processing Record 10 of Set 3 | hurricane
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | yar-sale
# Processing Record 14 of Set 3 | cape town
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | cherskiy
# Processing Record 19 of Set 3 | kieta
# Processing Record 20 of Set 3 | batemans bay
# Processing Record 21 of Set 3 | lang suan
# Processing Record 22 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 3 | high rock
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | jiutai
# Processing Record 26 of Set 3 | muros
# Processing Record 27 of Set 3 | wschowa
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | korla
# Processing Record 30 of Set 3 | inongo
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | waddan
# Processing Record 35 of Set 3 | ulladulla
# Processing Record 36 of Set 3 | katubao
# Processing Record 37 of Set 3 | sibu
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | mayor pablo lagerenza
# Processing Record 40 of Set 3 | puerto ayora
# Processing Record 41 of Set 3 | port-gentil
# Processing Record 42 of Set 3 | lompoc
# Processing Record 43 of Set 3 | seoul
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 3 | nome
# Processing Record 48 of Set 3 | la ronge
# Processing Record 49 of Set 3 | kuching
# Processing Record 50 of Set 3 | fortuna
# Processing Record 1 of Set 4 | lata
# Processing Record 2 of Set 4 | aksay
# Processing Record 3 of Set 4 | saldanha
# Processing Record 4 of Set 4 | himare
# Processing Record 5 of Set 4 | rivadavia
# Processing Record 6 of Set 4 | isangel
# Processing Record 7 of Set 4 | terney
# Processing Record 8 of Set 4 | vyazemskiy
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | abu samrah
# Processing Record 11 of Set 4 | sao filipe
# Processing Record 12 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 4 | provideniya
# Processing Record 14 of Set 4 | marsa matruh
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | lianzhou
# Processing Record 17 of Set 4 | broome
# Processing Record 18 of Set 4 | pisco
# Processing Record 19 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 21 of Set 4 | oktyabrskiy
# Processing Record 22 of Set 4 | spearfish
# Processing Record 23 of Set 4 | bouafle
# Processing Record 24 of Set 4 | broken hill
# Processing Record 25 of Set 4 | fianga
# City not found. Skipping...
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | grindavik
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | aksarka
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | natitingou
# Processing Record 33 of Set 4 | gunjur
# Processing Record 34 of Set 4 | sept-iles
# Processing Record 35 of Set 4 | mildura
# Processing Record 36 of Set 4 | homer
# Processing Record 37 of Set 4 | fernley
# Processing Record 38 of Set 4 | aykhal
# Processing Record 39 of Set 4 | correntina
# Processing Record 40 of Set 4 | la union
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | petatlan
# Processing Record 43 of Set 4 | saskylakh
# Processing Record 44 of Set 4 | phangnga
# Processing Record 45 of Set 4 | peniche
# Processing Record 46 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 4 | mendi
# Processing Record 49 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 4 | teguise
# Processing Record 1 of Set 5 | bandarbeyla
# Processing Record 2 of Set 5 | hambantota
# Processing Record 3 of Set 5 | rocha
# Processing Record 4 of Set 5 | tilichiki
# Processing Record 5 of Set 5 | emba
# Processing Record 6 of Set 5 | quesnel
# Processing Record 7 of Set 5 | xining
# Processing Record 8 of Set 5 | lodja
# Processing Record 9 of Set 5 | solwezi
# Processing Record 10 of Set 5 | nykoping
# Processing Record 11 of Set 5 | bambous virieux
# Processing Record 12 of Set 5 | strezhevoy
# Processing Record 13 of Set 5 | dalbeattie
# Processing Record 14 of Set 5 | agadir
# Processing Record 15 of Set 5 | berlevag
# Processing Record 16 of Set 5 | bengkulu
# Processing Record 17 of Set 5 | mudbidri
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | baykit
# Processing Record 20 of Set 5 | khoy
# Processing Record 21 of Set 5 | mount hagen
# Processing Record 22 of Set 5 | tasiilaq
# Processing Record 23 of Set 5 | pearl
# Processing Record 24 of Set 5 | anloga
# Processing Record 25 of Set 5 | gimli
# Processing Record 26 of Set 5 | manzhouli
# Processing Record 27 of Set 5 | fort nelson
# Processing Record 28 of Set 5 | norman wells
# Processing Record 29 of Set 5 | ossora
# Processing Record 30 of Set 5 | huarmey
# Processing Record 31 of Set 5 | guerrero negro
# Processing Record 32 of Set 5 | piedade
# Processing Record 33 of Set 5 | tual
# Processing Record 34 of Set 5 | benguela
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | chumikan
# Processing Record 37 of Set 5 | coffeyville
# Processing Record 38 of Set 5 | muravlenko
# Processing Record 39 of Set 5 | sao joao da barra
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | kantabanji
# Processing Record 43 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 5 | soyo
# Processing Record 45 of Set 5 | port hedland
# Processing Record 46 of Set 5 | khandagayty
# Processing Record 47 of Set 5 | montague
# Processing Record 48 of Set 5 | matagami
# Processing Record 49 of Set 5 | dmitriyevka
# Processing Record 50 of Set 5 | flinders
# Processing Record 1 of Set 6 | richards bay
# Processing Record 2 of Set 6 | gamba
# Processing Record 3 of Set 6 | port lincoln
# Processing Record 4 of Set 6 | oussouye
# Processing Record 5 of Set 6 | altay
# Processing Record 6 of Set 6 | leningradskiy
# Processing Record 7 of Set 6 | dunedin
# Processing Record 8 of Set 6 | eirunepe
# Processing Record 9 of Set 6 | fort-shevchenko
# Processing Record 10 of Set 6 | genc
# Processing Record 11 of Set 6 | pirdop
# Processing Record 12 of Set 6 | ipixuna
# Processing Record 13 of Set 6 | elizabeth city
# Processing Record 14 of Set 6 | chingirlau
# Processing Record 15 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 6 | diapaga
# Processing Record 17 of Set 6 | celestun
# Processing Record 18 of Set 6 | dera din panah
# City not found. Skipping...
# Processing Record 19 of Set 6 | tura
# Processing Record 20 of Set 6 | rock sound
# Processing Record 21 of Set 6 | lac du bonnet
# Processing Record 22 of Set 6 | kavieng
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | maun
# Processing Record 25 of Set 6 | coruripe
# Processing Record 26 of Set 6 | tabou
# Processing Record 27 of Set 6 | khowai
# Processing Record 28 of Set 6 | samarai
# Processing Record 29 of Set 6 | dosso
# Processing Record 30 of Set 6 | lewisville
# Processing Record 31 of Set 6 | peruibe
# Processing Record 32 of Set 6 | mareeba
# Processing Record 33 of Set 6 | aktau
# Processing Record 34 of Set 6 | jalu
# Processing Record 35 of Set 6 | pacific grove
# Processing Record 36 of Set 6 | lasa
# Processing Record 37 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 38 of Set 6 | buchanan
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | jamsa
# Processing Record 41 of Set 6 | zheleznodorozhnyy
# Processing Record 42 of Set 6 | mbanza-ngungu
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | dakoro
# Processing Record 45 of Set 6 | beausoleil
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | saint-louis
# Processing Record 48 of Set 6 | srivardhan
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | arman
# Processing Record 1 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 7 | tuatapere
# Processing Record 3 of Set 7 | adjumani
# Processing Record 4 of Set 7 | katsina
# Processing Record 5 of Set 7 | shieli
# Processing Record 6 of Set 7 | newton stewart
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | tomatlan
# Processing Record 9 of Set 7 | mao
# Processing Record 10 of Set 7 | sisimiut
# Processing Record 11 of Set 7 | stephenville
# Processing Record 12 of Set 7 | maragogi
# Processing Record 13 of Set 7 | adeje
# Processing Record 14 of Set 7 | karaton
# Processing Record 15 of Set 7 | kijang
# Processing Record 16 of Set 7 | takapau
# Processing Record 17 of Set 7 | nouadhibou
# Processing Record 18 of Set 7 | sassandra
# Processing Record 19 of Set 7 | kapit
# Processing Record 20 of Set 7 | klyuchi
# Processing Record 21 of Set 7 | moron
# Processing Record 22 of Set 7 | coahuayana
# Processing Record 23 of Set 7 | olinda
# Processing Record 24 of Set 7 | kachiry
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | shache
# Processing Record 28 of Set 7 | chokwe
# Processing Record 29 of Set 7 | discovery bay
# Processing Record 30 of Set 7 | jumla
# Processing Record 31 of Set 7 | severo-kurilsk
# Processing Record 32 of Set 7 | wamba
# Processing Record 33 of Set 7 | grand bend
# Processing Record 34 of Set 7 | adrar
# Processing Record 35 of Set 7 | hisua
# Processing Record 36 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 7 | fivizzano
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | banda aceh
# Processing Record 40 of Set 7 | terre haute
# Processing Record 41 of Set 7 | geraldton
# Processing Record 42 of Set 7 | roebourne
# Processing Record 43 of Set 7 | anchorage
# Processing Record 44 of Set 7 | pavlovsk
# Processing Record 45 of Set 7 | olga
# Processing Record 46 of Set 7 | duluth
# Processing Record 47 of Set 7 | whitianga
# Processing Record 48 of Set 7 | gainesville
# Processing Record 49 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 7 | bumba
# Processing Record 1 of Set 8 | amanganj
# Processing Record 2 of Set 8 | eureka
# Processing Record 3 of Set 8 | marystown
# Processing Record 4 of Set 8 | zhigansk
# Processing Record 5 of Set 8 | mandalgovi
# Processing Record 6 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 8 | iqaluit
# Processing Record 8 of Set 8 | rorvik
# Processing Record 9 of Set 8 | magadan
# Processing Record 10 of Set 8 | lavrentiya
# Processing Record 11 of Set 8 | mokhsogollokh
# Processing Record 12 of Set 8 | gazli
# Processing Record 13 of Set 8 | jutai
# Processing Record 14 of Set 8 | salalah
# Processing Record 15 of Set 8 | nsanje
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | chernyshevskiy
# Processing Record 18 of Set 8 | khilok
# Processing Record 19 of Set 8 | cervo
# Processing Record 20 of Set 8 | northam
# Processing Record 21 of Set 8 | havre-saint-pierre
# Processing Record 22 of Set 8 | sioux lookout
# Processing Record 23 of Set 8 | xuddur
# Processing Record 24 of Set 8 | axim
# Processing Record 25 of Set 8 | merauke
# Processing Record 26 of Set 8 | magburaka
# Processing Record 27 of Set 8 | basco
# Processing Record 28 of Set 8 | oranjemund
# Processing Record 29 of Set 8 | tlaxco
# Processing Record 30 of Set 8 | harper
# Processing Record 31 of Set 8 | kalmunai
# Processing Record 32 of Set 8 | stornoway
# Processing Record 33 of Set 8 | pinega
# Processing Record 34 of Set 8 | ozark
# Processing Record 35 of Set 8 | paysandu
# Processing Record 36 of Set 8 | ceica
# Processing Record 37 of Set 8 | kaniama
# Processing Record 38 of Set 8 | jishui
# Processing Record 39 of Set 8 | fukue
# Processing Record 40 of Set 8 | hovd
# Processing Record 41 of Set 8 | southbridge
# Processing Record 42 of Set 8 | auki
# Processing Record 43 of Set 8 | iquitos
# Processing Record 44 of Set 8 | kizema
# Processing Record 45 of Set 8 | bintulu
# Processing Record 46 of Set 8 | majene
# Processing Record 47 of Set 8 | zvishavane
# Processing Record 48 of Set 8 | favara
# Processing Record 49 of Set 8 | komsomolskiy
# Processing Record 50 of Set 8 | te anau
# Processing Record 1 of Set 9 | alofi
# Processing Record 2 of Set 9 | kahului
# Processing Record 3 of Set 9 | virginia beach
# Processing Record 4 of Set 9 | srandakan
# Processing Record 5 of Set 9 | taseyevo
# Processing Record 6 of Set 9 | keetmanshoop
# Processing Record 7 of Set 9 | beringovskiy
# Processing Record 8 of Set 9 | lannion
# Processing Record 9 of Set 9 | tygda
# Processing Record 10 of Set 9 | yerbogachen
# Processing Record 11 of Set 9 | rafai
# Processing Record 12 of Set 9 | sale
# Processing Record 13 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 9 | yatou
# Processing Record 15 of Set 9 | baiquan
# Processing Record 16 of Set 9 | aklavik
# Processing Record 17 of Set 9 | palestine
# Processing Record 18 of Set 9 | phoenix
# Processing Record 19 of Set 9 | burica
# City not found. Skipping...
# Processing Record 20 of Set 9 | shibetsu
# Processing Record 21 of Set 9 | chateaubelair
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | marienburg
# Processing Record 24 of Set 9 | carutapera
# Processing Record 25 of Set 9 | kingaroy
# Processing Record 26 of Set 9 | touros
# Processing Record 27 of Set 9 | kazanskoye
# Processing Record 28 of Set 9 | imisli
# City not found. Skipping...
# Processing Record 29 of Set 9 | chiredzi
# Processing Record 30 of Set 9 | qui nhon
# Processing Record 31 of Set 9 | chimore
# Processing Record 32 of Set 9 | lang son
# Processing Record 33 of Set 9 | montrose
# Processing Record 34 of Set 9 | nianzishan
# Processing Record 35 of Set 9 | porto novo
# Processing Record 36 of Set 9 | otradnoye
# Processing Record 37 of Set 9 | yaan
# Processing Record 38 of Set 9 | miraflores
# Processing Record 39 of Set 9 | togur
# Processing Record 40 of Set 9 | padang
# Processing Record 41 of Set 9 | camopi
# Processing Record 42 of Set 9 | puerto leguizamo
# Processing Record 43 of Set 9 | gweta
# Processing Record 44 of Set 9 | nyurba
# Processing Record 45 of Set 9 | letogo
# City not found. Skipping...
# Processing Record 46 of Set 9 | pangnirtung
# Processing Record 47 of Set 9 | santa rosa
# Processing Record 48 of Set 9 | rio gallegos
# Processing Record 49 of Set 9 | havoysund
# Processing Record 50 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 1 of Set 10 | bose
# Processing Record 2 of Set 10 | jinchang
# Processing Record 3 of Set 10 | voznesenye
# Processing Record 4 of Set 10 | verkhoyansk
# Processing Record 5 of Set 10 | longyearbyen
# Processing Record 6 of Set 10 | baiyin
# Processing Record 7 of Set 10 | darhan
# Processing Record 8 of Set 10 | college
# Processing Record 9 of Set 10 | palmital
# Processing Record 10 of Set 10 | waingapu
# Processing Record 11 of Set 10 | manggar
# Processing Record 12 of Set 10 | henties bay
# Processing Record 13 of Set 10 | airai
# Processing Record 14 of Set 10 | kon tum
# Processing Record 15 of Set 10 | osorno
# Processing Record 16 of Set 10 | novokayakent
# Processing Record 17 of Set 10 | akdepe
# Processing Record 18 of Set 10 | boksitogorsk
# Processing Record 19 of Set 10 | pitimbu
# Processing Record 20 of Set 10 | kalulushi
# Processing Record 21 of Set 10 | fairbanks
# Processing Record 22 of Set 10 | yenagoa
# Processing Record 23 of Set 10 | port macquarie
# Processing Record 24 of Set 10 | westport
# Processing Record 25 of Set 10 | mvuma
# Processing Record 26 of Set 10 | victoria point
# Processing Record 27 of Set 10 | kayes
# Processing Record 28 of Set 10 | chadan
# Processing Record 29 of Set 10 | ayan
# Processing Record 30 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 10 | sao mateus
# Processing Record 33 of Set 10 | alvaraes
# Processing Record 34 of Set 10 | hirara
# Processing Record 35 of Set 10 | omsukchan
# Processing Record 36 of Set 10 | sibolga
# Processing Record 37 of Set 10 | kuah
# Processing Record 38 of Set 10 | kodiak
# Processing Record 39 of Set 10 | meulaboh
# Processing Record 40 of Set 10 | kiama
# Processing Record 41 of Set 10 | muroto
# Processing Record 42 of Set 10 | alcantara
# Processing Record 43 of Set 10 | itarema
# Processing Record 44 of Set 10 | baherden
# Processing Record 45 of Set 10 | damietta
# Processing Record 46 of Set 10 | dudinka
# Processing Record 47 of Set 10 | pala
# Processing Record 48 of Set 10 | alyangula
# Processing Record 49 of Set 10 | ilulissat
# Processing Record 50 of Set 10 | bushehr
# Processing Record 1 of Set 11 | matara
# Processing Record 2 of Set 11 | chengde
# Processing Record 3 of Set 11 | rawlins
# Processing Record 4 of Set 11 | la orilla
# Processing Record 5 of Set 11 | pochutla
# Processing Record 6 of Set 11 | townsville
# Processing Record 7 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 8 of Set 11 | flin flon
# Processing Record 9 of Set 11 | fort walton beach
# Processing Record 10 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 11 | conde
# Processing Record 12 of Set 11 | mahanje
# Processing Record 13 of Set 11 | wajima
# Processing Record 14 of Set 11 | amargosa
# Processing Record 15 of Set 11 | lamu
# Processing Record 16 of Set 11 | ouadda
# Processing Record 17 of Set 11 | sampit
# Processing Record 18 of Set 11 | gat
# Processing Record 19 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 11 | wajir
# Processing Record 21 of Set 11 | saint george
# Processing Record 22 of Set 11 | ust-koksa
# Processing Record 23 of Set 11 | taoudenni
# Processing Record 24 of Set 11 | yulara
# Processing Record 25 of Set 11 | winnemucca
# Processing Record 26 of Set 11 | abrau-dyurso
# Processing Record 27 of Set 11 | najran
# Processing Record 28 of Set 11 | omboue
# Processing Record 29 of Set 11 | kindersley
# Processing Record 30 of Set 11 | tateyama
# Processing Record 31 of Set 11 | williston
# Processing Record 32 of Set 11 | tonj
# Processing Record 33 of Set 11 | slobozia
# Processing Record 34 of Set 11 | kailua
# Processing Record 35 of Set 11 | maniitsoq
# Processing Record 36 of Set 11 | mumford
# Processing Record 37 of Set 11 | belmonte
# Processing Record 38 of Set 11 | mitsamiouli
# Processing Record 39 of Set 11 | punta alta
# Processing Record 40 of Set 11 | iskilip
# Processing Record 41 of Set 11 | fram
# Processing Record 42 of Set 11 | poso
# Processing Record 43 of Set 11 | nikolayevsk-na-amure
# Processing Record 44 of Set 11 | velsk
# Processing Record 45 of Set 11 | lakselv
# Processing Record 46 of Set 11 | amga
# Processing Record 47 of Set 11 | onguday
# Processing Record 48 of Set 11 | maroantsetra
# Processing Record 49 of Set 11 | hualmay
# Processing Record 50 of Set 11 | arinos
# Processing Record 1 of Set 12 | haicheng
# Processing Record 2 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 12 | margate
# Processing Record 4 of Set 12 | chalchihuites
# Processing Record 5 of Set 12 | antsohihy
# Processing Record 6 of Set 12 | blythe
# Processing Record 7 of Set 12 | mabaruma
# Processing Record 8 of Set 12 | dhidhdhoo
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | varna
# Processing Record 11 of Set 12 | krasnaya gora
# Processing Record 12 of Set 12 | danjiangkou
# Processing Record 13 of Set 12 | santa barbara
# Processing Record 14 of Set 12 | poum
# Processing Record 15 of Set 12 | kozhevnikovo
# Processing Record 16 of Set 12 | masuguru
# Processing Record 17 of Set 12 | talara
# Processing Record 18 of Set 12 | kenai
# Processing Record 19 of Set 12 | los arabos
# Processing Record 20 of Set 12 | sasovo
# Processing Record 21 of Set 12 | ulcinj
# Processing Record 22 of Set 12 | bandar-e lengeh
# Processing Record 23 of Set 12 | patti
# Processing Record 24 of Set 12 | bay roberts
# Processing Record 25 of Set 12 | tabuk
# Processing Record 26 of Set 12 | mount gambier
# Processing Record 27 of Set 12 | lichtenburg
# Processing Record 28 of Set 12 | kutum
# Processing Record 29 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 30 of Set 12 | catia la mar
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | baoro
# Processing Record 33 of Set 12 | fare
# Processing Record 34 of Set 12 | bodmin
# Processing Record 35 of Set 12 | uyemskiy
# Processing Record 36 of Set 12 | antalaha
# Processing Record 37 of Set 12 | iralaya
# Processing Record 38 of Set 12 | san vicente
# Processing Record 39 of Set 12 | atambua
# Processing Record 40 of Set 12 | sterlibashevo
# Processing Record 41 of Set 12 | lancaster
# Processing Record 42 of Set 12 | never
# Processing Record 43 of Set 12 | pizarro
# Processing Record 44 of Set 12 | plettenberg bay
# Processing Record 45 of Set 12 | karratha
# Processing Record 46 of Set 12 | gushikawa
# Processing Record 47 of Set 12 | tessalit
# Processing Record 48 of Set 12 | husavik
# Processing Record 49 of Set 12 | jijiga
# Processing Record 50 of Set 12 | ladispoli
# Processing Record 1 of Set 13 | steubenville
# Processing Record 2 of Set 13 | shakawe
# Processing Record 3 of Set 13 | torrelavega
# Processing Record 4 of Set 13 | la macarena
# Processing Record 5 of Set 13 | palanga
# Processing Record 6 of Set 13 | sindou
# Processing Record 7 of Set 13 | pemangkat
# Processing Record 8 of Set 13 | phek
# Processing Record 9 of Set 13 | lilongwe
# Processing Record 10 of Set 13 | udachnyy
# Processing Record 11 of Set 13 | cadereyta
# Processing Record 12 of Set 13 | ponta delgada
# Processing Record 13 of Set 13 | riyadh
# Processing Record 14 of Set 13 | madingou
# Processing Record 15 of Set 13 | todos santos
# Processing Record 16 of Set 13 | funtua
# Processing Record 17 of Set 13 | gornopravdinsk
# Processing Record 18 of Set 13 | tromso
# Processing Record 19 of Set 13 | barberton
# Processing Record 20 of Set 13 | florianopolis
# Processing Record 21 of Set 13 | lorengau
# Processing Record 22 of Set 13 | burlington
# Processing Record 23 of Set 13 | alice springs
# Processing Record 24 of Set 13 | porto walter
# Processing Record 25 of Set 13 | port blair
# Processing Record 26 of Set 13 | anadyr
# Processing Record 27 of Set 13 | kismayo
# Processing Record 28 of Set 13 | kavaratti
# Processing Record 29 of Set 13 | viedma
# Processing Record 30 of Set 13 | nantucket
# Processing Record 31 of Set 13 | jeremoabo
# Processing Record 32 of Set 13 | christchurch
# Processing Record 33 of Set 13 | binzhou
# Processing Record 34 of Set 13 | hami
# Processing Record 35 of Set 13 | byron bay
# Processing Record 36 of Set 13 | bure
# Processing Record 37 of Set 13 | krasnoselkup
# Processing Record 38 of Set 13 | palauig
# Processing Record 39 of Set 13 | yolombo
# Processing Record 40 of Set 13 | la rioja
# Processing Record 41 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 13 | nynashamn
# Processing Record 43 of Set 13 | tucuman
# Processing Record 44 of Set 13 | grants
# Processing Record 45 of Set 13 | mapiri
# Processing Record 46 of Set 13 | ambilobe
# Processing Record 47 of Set 13 | dzidzantun
# Processing Record 48 of Set 13 | rach gia
# Processing Record 49 of Set 13 | san pedro
# Processing Record 50 of Set 13 | katobu
# Processing Record 1 of Set 14 | san juan
# Processing Record 2 of Set 14 | egvekinot
# Processing Record 3 of Set 14 | lyngseidet
# Processing Record 4 of Set 14 | bereda
# Processing Record 5 of Set 14 | north bend
# Processing Record 6 of Set 14 | hede
# Processing Record 7 of Set 14 | melchor de mencos
# Processing Record 8 of Set 14 | makakilo city
# Processing Record 9 of Set 14 | brandon
# Processing Record 10 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | koraput
# Processing Record 12 of Set 14 | sebrovo
# Processing Record 13 of Set 14 | houston
# Processing Record 14 of Set 14 | nhulunbuy
# Processing Record 15 of Set 14 | launceston
# Processing Record 16 of Set 14 | gravdal
# Processing Record 17 of Set 14 | tigil
# Processing Record 18 of Set 14 | alta floresta
# Processing Record 19 of Set 14 | jardim
# Processing Record 20 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 14 | comodoro rivadavia
# Processing Record 22 of Set 14 | along
# Processing Record 23 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 14 | nachalovo
# Processing Record 25 of Set 14 | pueblo
# Processing Record 26 of Set 14 | mancio lima
# Processing Record 27 of Set 14 | namatanai
# Processing Record 28 of Set 14 | ixtapa
# Processing Record 29 of Set 14 | kudahuvadhoo
# Processing Record 30 of Set 14 | itoman
# Processing Record 31 of Set 14 | moindou
# Processing Record 32 of Set 14 | yumen
# Processing Record 33 of Set 14 | pimenta bueno
# Processing Record 34 of Set 14 | yarada
# Processing Record 35 of Set 14 | morant bay
# Processing Record 36 of Set 14 | karla
# Processing Record 37 of Set 14 | natal
# Processing Record 38 of Set 14 | east wenatchee bench
# Processing Record 39 of Set 14 | sabang
# Processing Record 40 of Set 14 | morehead
# Processing Record 41 of Set 14 | ha tinh
# Processing Record 42 of Set 14 | katherine
# Processing Record 43 of Set 14 | nioki
# Processing Record 44 of Set 14 | marsaxlokk
# Processing Record 45 of Set 14 | krasnyy yar
# Processing Record 46 of Set 14 | genhe
# Processing Record 47 of Set 14 | whitehorse
# Processing Record 48 of Set 14 | cozumel
# Processing Record 49 of Set 14 | qinggang
# Processing Record 50 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 15 | sakakah
# Processing Record 2 of Set 15 | juneau
# Processing Record 3 of Set 15 | mayumba
# Processing Record 4 of Set 15 | shingu
# Processing Record 5 of Set 15 | pangody
# Processing Record 6 of Set 15 | sault sainte marie
# Processing Record 7 of Set 15 | smirnykh
# Processing Record 8 of Set 15 | wanning
# Processing Record 9 of Set 15 | ambatondrazaka
# Processing Record 10 of Set 15 | ayacucho
# Processing Record 11 of Set 15 | mikkeli
# Processing Record 12 of Set 15 | mazara del vallo
# Processing Record 13 of Set 15 | port hardy
# Processing Record 14 of Set 15 | port-cartier
# Processing Record 15 of Set 15 | derzhavinsk
# Processing Record 16 of Set 15 | quisqueya
# Processing Record 17 of Set 15 | bardiyah
# Processing Record 18 of Set 15 | dom pedrito
# Processing Record 19 of Set 15 | maceio
# Processing Record 20 of Set 15 | tambo
# Processing Record 21 of Set 15 | chapais
# Processing Record 22 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 23 of Set 15 | timizart
# Processing Record 24 of Set 15 | tambura
# Processing Record 25 of Set 15 | vardo
# Processing Record 26 of Set 15 | sioni
# Processing Record 27 of Set 15 | russell
# Processing Record 28 of Set 15 | ibotirama
# Processing Record 29 of Set 15 | mezen
# Processing Record 30 of Set 15 | huadian
# Processing Record 31 of Set 15 | sainte-suzanne
# Processing Record 32 of Set 15 | janesville
# Processing Record 33 of Set 15 | gull lake
# Processing Record 34 of Set 15 | gigmoto
# Processing Record 35 of Set 15 | kenitra
# Processing Record 36 of Set 15 | firozpur
# Processing Record 37 of Set 15 | ondjiva
# Processing Record 38 of Set 15 | mount isa
# Processing Record 39 of Set 15 | morondava
# Processing Record 40 of Set 15 | umm kaddadah
# Processing Record 41 of Set 15 | mangaratiba
# Processing Record 42 of Set 15 | neepawa
# Processing Record 43 of Set 15 | andenes
# Processing Record 44 of Set 15 | londrina
# Processing Record 45 of Set 15 | san policarpo
# Processing Record 46 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 15 | kungurtug
# Processing Record 48 of Set 15 | ewa beach
# Processing Record 49 of Set 15 | uruguaiana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
 city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp Current Description  \
# 0            Georgetown   5.4112  100.3354     78.80          few clouds
# 1             Thinadhoo   0.5333   72.9333     81.43       broken clouds
# 2            Chokurdakh  70.6333  147.9167     -5.24     overcast clouds
# 3               Rikitea -23.1203 -134.9692     78.57       broken clouds
# 4  Vila Franca Do Campo  37.7167  -25.4333     61.00          light rain
# 5      Praia Da Vitoria  38.7333  -27.0667     60.80          light rain
# 6              Coquimbo -29.9533  -71.3436     66.20           clear sky
# 7                Avarua -21.2078 -159.7750     84.20          few clouds
# 8             Busselton -33.6500  115.3333     59.00           clear sky
# 9                 Kapaa  22.0752 -159.3190     77.00           clear sky
#
#    Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0           0.00            0.0        88          20        5.75      MY
# 1           0.00            0.0        76          59       13.96      MV
# 2           0.00            0.0        91         100        9.40      RU
# 3           0.00            0.0        67          55        7.11      PF
# 4           0.14            0.0        88          40       17.27      PT
# 5           0.00            0.0        94          40       18.86      PT
# 6           0.00            0.0        63           0       14.97      CL
# 7           0.00            0.0        79          16       12.66      CK
# 8           0.00            0.0        80           0        5.01      AU
# 9           0.00            0.0        83           1        4.38      US

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description", "Rain (inches)","Snow (inches)"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Georgetown      MY   5.4112  100.3354     78.80        88
# 1             Thinadhoo      MV   0.5333   72.9333     81.43        76
# 2            Chokurdakh      RU  70.6333  147.9167     -5.24        91
# 3               Rikitea      PF -23.1203 -134.9692     78.57        67
# 4  Vila Franca Do Campo      PT  37.7167  -25.4333     61.00        88
# 5      Praia Da Vitoria      PT  38.7333  -27.0667     60.80        94
# 6              Coquimbo      CL -29.9533  -71.3436     66.20        63
# 7                Avarua      CK -21.2078 -159.7750     84.20        79
# 8             Busselton      AU -33.6500  115.3333     59.00        80
# 9                 Kapaa      US  22.0752 -159.3190     77.00        83
#
#    Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0          20        5.75          few clouds           0.00            0.0
# 1          59       13.96       broken clouds           0.00            0.0
# 2         100        9.40     overcast clouds           0.00            0.0
# 3          55        7.11       broken clouds           0.00            0.0
# 4          40       17.27          light rain           0.14            0.0
# 5          40       18.86          light rain           0.00            0.0
# 6           0       14.97           clear sky           0.00            0.0
# 7          16       12.66          few clouds           0.00            0.0
# 8           0        5.01           clear sky           0.00            0.0
# 9           1        4.38           clear sky           0.00            0.0

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# Rain (inches)          float64
# Snow (inches)          float64
# dtype: object

# %%
raining_cities = city_data_df.loc[city_data_df['Rain (inches)']>0]
raining_cities
# Out:
#                         City Country      Lat       Lng  Max Temp  Humidity  \
# 4       Vila Franca Do Campo      PT  37.7167  -25.4333     61.00        88
# 33                    Dingle      PH  10.9995  122.6711     74.25        93
# 34   San Carlos De Bariloche      AR -41.1456  -71.3082     51.80        62
# 37                     Vaini      TO -21.2000 -175.2000     84.20        79
# 39                  Manicore      BR  -5.8092  -61.3003     80.42        82
# ..                       ...     ...      ...       ...       ...       ...
# 658                 Ayacucho      PE -13.1583  -74.2239     68.77        47
# 660         Mazara Del Vallo      IT  37.6641   12.5880     55.00        87
# 678           Sainte-Suzanne      RE -20.9061   55.6089     80.60        74
# 681                  Gigmoto      PH  13.7796  124.3900     78.24        86
# 695               Uruguaiana      BR -29.7547  -57.0883     87.80        70
#
#      Cloudiness  Wind Speed   Current Description  Rain (inches)  \
# 4            40       17.27            light rain         0.1400
# 33           14        6.98         moderate rain         1.2936
# 34           75       20.71            light rain         1.0000
# 37           40        9.22            light rain         0.2400
# 39           91        2.57  heavy intensity rain        11.5310
# ..          ...         ...                   ...            ...
# 658          60        6.67         moderate rain         1.1000
# 660          40       26.46            light rain         0.4200
# 678          75        8.05            light rain         0.2100
# 681         100       14.52         moderate rain         1.2654
# 695          90        5.75         moderate rain         1.8700
#
#      Snow (inches)
# 4              0.0
# 33             0.0
# 34             0.0
# 37             0.0
# 39             0.0
# ..             ...
# 658            0.0
# 660            0.0
# 678            0.0
# 681            0.0
# 695            0.0
#
# [82 rows x 11 columns]

# %%
snowing_cities = city_data_df.loc[city_data_df['Snow (inches)']>0]
snowing_cities
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 20         Belaya Gora      RU  68.5333  146.4167    -17.14        89
# 63              Torbay      CA  47.6666  -52.7314     32.00        93
# 69             Paamiut      GL  61.9940  -49.6678     28.04        96
# 92           Upernavik      GL  72.7868  -56.1549     15.19        96
# 129         Nikolskoye      RU  59.7035   30.7861      8.01        85
# 140             Terney      RU  45.0503  136.6092     15.62        92
# 147         Nanortalik      GL  60.1432  -45.2371     27.82        97
# 157          Grindavik      IS  63.8424  -22.4338     33.80       100
# 188         Strezhevoy      RU  60.7333   77.5889      5.00        85
# 189         Dalbeattie      GB  54.9328   -3.8227     34.00        88
# 197           Tasiilaq      GL  65.6145  -37.6368     32.00        86
# 203       Norman Wells      CA  65.2820 -126.8329      5.00        78
# 213         Muravlenko      RU  63.7898   74.5230      1.87        94
# 238         Chingirlau      KZ  51.0950   54.0814     24.53        97
# 261  Zheleznodorozhnyy      RU  55.7503   38.0042      8.60        85
# 349              Ozark      US  37.0209  -93.2060     33.01        85
# 383           Shibetsu      JP  43.6590  145.1320     29.62        98
# 398          Otradnoye      RU  59.7775   30.8181      8.01        85
# 401              Togur      RU  58.3631   82.8265     -0.65        93
# 481       Abrau-Dyurso      RU  44.6900   37.5900     33.01        93
# 513               Asau      RO  46.4333   26.4000     21.00        63
# 524             Sasovo      RU  54.3537   41.9199     11.28        96
# 528        Bay Roberts      CA  47.5999  -53.2648     32.00        90
# 543      Sterlibashevo      RU  53.4376   55.2578     15.62        95
# 554       Steubenville      US  40.3698  -80.6340     35.01        93
# 570     Gornopravdinsk      RU  60.0500   69.9000      9.36        95
# 571             Tromso      NO  69.6496   18.9570     33.80        93
# 604          Egvekinot      RU  66.3167 -179.1667     -6.34        93
# 605         Lyngseidet      NO  69.5763   20.2189     37.40        93
# 613            Sebrovo      RU  50.0981   43.2976     19.99        92
# 635              Karla      EE  59.3723   24.9275     17.60        86
# 650             Juneau      US  58.3019 -134.4197     42.80        81
# 653            Pangody      RU  65.8500   74.4859     -0.13        93
# 672              Vardo      NO  70.3705   31.1107     32.00        86
#
#      Cloudiness  Wind Speed Current Description  Rain (inches)  Snow (inches)
# 20          100        5.03          light snow           0.00         0.1200
# 63           90       21.85          light snow           0.00         0.2500
# 69          100       15.26          light snow           0.00         0.4300
# 92          100        3.74          light snow           0.00         0.1800
# 129          75        2.24                snow           0.00         0.5600
# 140         100        9.24          light snow           0.00         0.1400
# 147          99        5.32          light snow           0.00         0.1500
# 157          90       27.63               sleet           0.00         2.7300
# 188          90       13.42                snow           0.00         0.7400
# 189         100        8.99          light snow           0.00         0.3000
# 197          90       16.11                snow           0.00         0.7700
# 203          90        8.05          light snow           0.00         0.1400
# 213         100       11.34          light snow           0.00         0.2400
# 238         100       15.01          light snow           0.00         0.2050
# 261           0        6.71          light snow           0.00         0.2100
# 349         100        8.01          light snow           0.00         0.3900
# 383         100       15.01          light snow           0.00         0.3366
# 398          75        2.24                snow           0.00         0.8200
# 401         100       10.42          light snow           0.00         0.1900
# 481          85        4.47                snow           0.00         0.9000
# 513         100        2.08          light snow           0.00         0.1900
# 524         100        9.10                snow           0.00         0.9990
# 528         100        5.99          light snow           0.00         0.3900
# 543         100       12.57          light snow           0.00         0.4832
# 554          90       10.36                snow           0.00         0.8700
# 570         100        9.37     overcast clouds           0.00         0.1000
# 571          75        4.61          light snow           0.00         0.3700
# 604         100       16.82          light snow           0.00         0.2000
# 605          75        4.61          light snow           0.00         0.2500
# 613         100       12.80                snow           0.00         0.6400
# 635          90        8.05          light snow           0.00         0.4500
# 650          90       13.80          light rain           0.25         2.2900
# 653         100        9.82          light snow           0.00         0.1600
# 672          75        5.75          light snow           0.00         0.1700

# %%
city_data_df.to_csv('../Data/WeatherPy_Database.csv')
